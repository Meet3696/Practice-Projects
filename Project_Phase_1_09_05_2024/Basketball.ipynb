# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings ('ignore')

# %%
data=pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Baseball/baseball.csv')

# %%
data.shape
# Out:
# (30, 17)

# %%
data.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
data.isnull().isna()
# Out:
#         W      R     AB      H     2B     3B     HR     BB     SO     SB  \
# 0   False  False  False  False  False  False  False  False  False  False
# 1   False  False  False  False  False  False  False  False  False  False
# 2   False  False  False  False  False  False  False  False  False  False
# 3   False  False  False  False  False  False  False  False  False  False
# 4   False  False  False  False  False  False  False  False  False  False
# 5   False  False  False  False  False  False  False  False  False  False
# 6   False  False  False  False  False  False  False  False  False  False
# 7   False  False  False  False  False  False  False  False  False  False
# 8   False  False  False  False  False  False  False  False  False  False
# 9   False  False  False  False  False  False  False  False  False  False
# 10  False  False  False  False  False  False  False  False  False  False
# 11  False  False  False  False  False  False  False  False  False  False
# ...

# %%
data.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
data.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
df.nunique().to_frame('No. of unique values')
# Out:
#      No. of unique values
# R                      28
# AB                     29
# H                      29
# 2B                     22
# 3B                     23
# HR                     27
# BB                     29
# SO                     29
# SB                     27
# ERA                    30
# CG                      9
# SHO                    12
# SV                     20
# E                      21

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
for i in data.columns:
  print(data[i].value_counts())
  print("\n")
# Out:
# W
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: count, dtype: int64
#
#
# R
# 689    2
# 696    2
# 724    1
# 647    1
# 650    1
# 720    1
# 667    1
# 626    1
# 573    1
# 613    1
# 703    1
# 683    1
# 640    1
# 655    1
# 697    1
# 694    1
# 656    1
# 661    1
# 729    1
# 751    1
# 748    1
# 644    1
# 713    1
# 764    1
# 891    1
# 622    1
# 669    1
# 737    1
# Name: count, dtype: int64
#
#
# AB
# 5485    2
# 5575    1
# 5631    1
# 5457    1
# 5649    1
# 5565    1
# 5385    1
# 5529    1
# 5420    1
# 5463    1
# 5428    1
# 5527    1
# 5571    1
# 5480    1
# 5491    1
# 5484    1
# 5467    1
# 5600    1
# 5544    1
# 5417    1
# 5459    1
# 5511    1
# 5640    1
# 5567    1
# 5509    1
# 5605    1
# 5533    1
# 5439    1
# 5572    1
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
X=data.drop(columns=["W"])
Y=data["W"]

# %%
sns.lmplot(x="R", y="W",data=data,palette='colorblind')

# %%
plt.scatter("R","W", data=data)
plt.xlabel("R")
plt.ylabel("W")
plt.show()

# %%
sns.lmplot(x="AB", y="W",data=data,palette='colorblind')

# %%
plt.scatter("AB","W", data=data)
plt.xlabel("AB")
plt.ylabel("W")
plt.show()

# %%
sns.lmplot(x="H", y="W",data=data,palette='colorblind')

# %%
plt.scatter("H","W", data=data)
plt.xlabel("H")
plt.ylabel("W")
plt.show()

# %%
sns.lmplot(x="2B", y="W",data=data,palette='colorblind')

# %%
plt.scatter("2B","W", data=data)
plt.xlabel("2B")
plt.ylabel("W")
plt.show()

# %%
sns.lmplot(x="3B", y="W",data=data,palette='colorblind')

# %%
plt.scatter("3B","W", data=data)
plt.xlabel("3B")
plt.ylabel("W")
plt.show()

# %%
sns.lmplot(x="HR", y="W",data=data,palette='colorblind')

# %%
plt.scatter("HR","W", data=data)
plt.xlabel("HR")
plt.ylabel("W")
plt.show()

# %%
sns.lmplot(x="BB", y="W",data=data,palette='colorblind')

# %%
plt.scatter("BB","W", data=data)
plt.xlabel("BB")
plt.ylabel("W")
plt.show()

# %%
sns.lmplot(x="SO", y="W",data=data,palette='colorblind')

# %%
plt.scatter("SO","W", data=data)
plt.xlabel("SO")
plt.ylabel("W")
plt.show()

# %%
sns.lmplot(x="SB", y="W",data=data,palette='colorblind')

# %%
plt.scatter("SB","W", data=data)
plt.xlabel("SB")
plt.ylabel("W")
plt.show()

# %%
sns.lmplot(x="RA", y="W",data=data,palette='colorblind')

# %%
plt.scatter("RA","W", data=data)
plt.xlabel("RA")
plt.ylabel("W")
plt.show()

# %%
sns.lmplot(x="ER", y="W",data=data,palette='colorblind')

# %%
plt.scatter("ER","W", data=data)
plt.xlabel("ER")
plt.ylabel("W")
plt.show()

# %%
sns.lmplot(x="ERA", y="W",data=data,palette='colorblind')

# %%
plt.scatter("ERA","W", data=data)
plt.xlabel("ERA")
plt.ylabel("W")
plt.show()

# %%
sns.lmplot(x="CG", y="W",data=data,palette='colorblind')

# %%
plt.scatter("CG","W", data=data)
plt.xlabel("CG")
plt.ylabel("W")
plt.show()

# %%
sns.lmplot(x="SHO", y="W",data=data,palette='colorblind')

# %%
plt.scatter("SHO","W", data=data)
plt.xlabel("SHO")
plt.ylabel("W")
plt.show()

# %%
sns.lmplot(x="SV", y="W",data=data,palette='colorblind')

# %%
plt.scatter("SV","W", data=data)
plt.xlabel("SV")
plt.ylabel("W")
plt.show()

# %%
sns.lmplot(x="E", y="W",data=data,palette='colorblind')

# %%
plt.scatter("E","W", data=data)
plt.xlabel("E")
plt.ylabel("W")
plt.show()

# %%
sns.pairplot(data,hue="W",palette="Dark2")
plt.show()

# %%
plt.figure(figsize=(10,50),facecolor="white")
plotnumber=1
for col in data:
  if plotnumber<=17:
    ax=plt.subplot(17,1,plotnumber)
    sns.boxplot(data[col],palette="Set2_r")
    plt.xlabel(col,fontsize=8)
    plt.yticks(rotation=0,fontsize=6)
  plotnumber+=1
plt.tight_layout()

# %%
data.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
data['R']=np.cbrt(data['R'])

# %%
data.skew()
# Out:
# W      0.047089
# R      0.892970
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
cor=data.corr()

# %%
cor
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.439027 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.439027  1.000000  0.332282  0.483362  0.564836 -0.053415  0.675069
# AB  -0.087947  0.332282  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.483362  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.564836  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.053415  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.675069 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.398238 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.038776 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081242  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.048267  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.046518  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
plt.figure(figsize=(20,15))
sns.heatmap(data.corr(),linewidths=0.1,fmt=".1g",linecolor='black',annot=True)
plt.yticks(rotation=0)
plt.show()

# %%
plt.scatter("RA","ER", data=data)
plt.xlabel("RA")
plt.ylabel("ER")
plt.show()

# %%
plt.scatter("ERA","ER", data=data)
plt.xlabel("ERA")
plt.ylabel("ER")
plt.show()

# %%
df=X.drop(columns=["RA","ER"])

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(df),columns=df.columns)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge
from sklearn.svm import SVR
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
maxAccu=0
maxRS=0

for i in range(1,300):
    x_train,x_test,y_train,y_test=train_test_split(df,Y,test_size=0.25,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i

print("maximum r2 score is ",maxAccu,"on Random state",maxRS)
# Out:
# maximum r2 score is  0.9407694397154424 on Random state 6

# %%
x_train,x_test,y_train,y_test=train_test_split(df,Y,test_size=0.25,random_state=i)

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
pred_LR=LR.predict(x_test)
pred_train=LR.predict(x_train)

print('R2_score:',r2_score(y_test,pred_LR))
print('R2_score on training Data:', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test,pred_LR))
print('Mean Squared Error:',mean_squared_error(y_test,pred_LR))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2_score: 0.7579515809390721
# R2_score on training Data: 96.77906257510702
# Mean Absolute Error: 3.066535629763612
# Mean Squared Error: 21.871343866083528
# Root Mean Squared Error: 4.676680859977889

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
pred_RFR=RFR.predict(x_test)
pred_train=RFR.predict(x_train)

print('R2_score:',r2_score(y_test,pred_RFR))
print('R2_score on training Data:', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test,pred_RFR))
print('Mean Squared Error:',mean_squared_error(y_test,pred_RFR))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# R2_score: 0.3077276154245202
# R2_score on training Data: 92.50912897822445
# Mean Absolute Error: 6.449999999999999
# Mean Squared Error: 62.55329999999999
# Root Mean Squared Error: 7.909064420018337

# %%
knn=KNN()
knn.fit(x_train,y_train)
pred_knn=knn.predict(x_test)
pred_train=knn.predict(x_train)

print('R2_score:',r2_score(y_test,pred_knn))
print('R2_score on training Data:', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test,pred_knn))
print('Mean Squared Error:',mean_squared_error(y_test,pred_knn))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred_knn)))
# Out:
# R2_score: -0.8902853190385607
# R2_score on training Data: 40.24359894711655
# Mean Absolute Error: 10.475
# Mean Squared Error: 170.80499999999995
# Root Mean Squared Error: 13.069238692441115

# %%
GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_GBR=GBR.predict(x_test)
pred_train=GBR.predict(x_train)

print('R2_score:',r2_score(y_test,pred_GBR))
print('R2_score on training Data:', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test,pred_GBR))
print('Mean Squared Error:',mean_squared_error(y_test,pred_GBR))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred_GBR)))
# Out:
# R2_score: 0.41322106766626765
# R2_score on training Data: 99.99999436379841
# Mean Absolute Error: 6.591361966154993
# Mean Squared Error: 53.02097758884335
# Root Mean Squared Error: 7.281550493462457

# %%
lasso=Lasso()
lasso.fit(x_train,y_train)
pred_lasso=lasso.predict(x_test)
pred_train=lasso.predict(x_train)

print('R2_score:',r2_score(y_test,pred_lasso))
print('R2_score on training Data:', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test,pred_lasso))
print('Mean Squared Error:',mean_squared_error(y_test,pred_lasso))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred_lasso)))
# Out:
# R2_score: 0.3850357776481309
# R2_score on training Data: 94.6699719356818
# Mean Absolute Error: 6.081146267500156
# Mean Squared Error: 55.56778277907592
# Root Mean Squared Error: 7.454380106962343

# %%
rd=Ridge()
rd.fit(x_train,y_train)
pred_rd=rd.predict(x_test)
pred_train=rd.predict(x_train)

print('R2_score:',r2_score(y_test,pred_rd))
print('R2_score on training Data:', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test,pred_rd))
print('Mean Squared Error:',mean_squared_error(y_test,pred_rd))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# R2_score: 0.5911272847226281
# R2_score on training Data: 96.22962498676195
# Mean Absolute Error: 4.563139464218018
# Mean Squared Error: 36.94548300701628
# Root Mean Squared Error: 6.078279609150625

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred_dtr=dtr.predict(x_test)
pred_train=dtr.predict(x_train)

print('R2_score:',r2_score(y_test,pred_dtr))
print('R2_score on training Data:', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test,pred_dtr))
print('Mean Squared Error:',mean_squared_error(y_test,pred_dtr))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred_dtr)))
# Out:
# R2_score: -0.3888984955905239
# R2_score on training Data: 100.0
# Mean Absolute Error: 9.75
# Mean Squared Error: 125.5
# Root Mean Squared Error: 11.20267825120404

# %%
svr=SVR()
svr.fit(x_train,y_train)
pred_svr=svr.predict(x_test)
pred_train=svr.predict(x_train)

print('R2_score:',r2_score(y_test,pred_svr))
print('R2_score on training Data:', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test,pred_svr))
print('Mean Squared Error:',mean_squared_error(y_test,pred_svr))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred_svr)))
# Out:
# R2_score: -0.3197931787648549
# R2_score on training Data: 0.09083734899814067
# Mean Absolute Error: 8.623090472507894
# Mean Squared Error: 119.25568676245555
# Root Mean Squared Error: 10.920425209782609

# %%
etr=ExtraTreesRegressor()
etr.fit(x_train,y_train)
pred_etr=etr.predict(x_test)
pred_train=etr.predict(x_train)

print('R2_score:',r2_score(y_test,pred_etr))
print('R2_score on training Data:', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test,pred_etr))
print('Mean Squared Error:',mean_squared_error(y_test,pred_etr))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred_etr)))
# Out:
# R2_score: 0.32309776932388024
# R2_score on training Data: 100.0
# Mean Absolute Error: 6.571250000000001
# Mean Squared Error: 61.16446250000001
# Root Mean Squared Error: 7.820771221561209

# %%
score=cross_val_score(LR,df,Y,cv=5,scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 score and cross validation score is:",(r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [ 0.65789003 -0.82668924  0.56567429  0.67222833  0.80179611]
# 0.3741799046419825
# Difference between R2 score and cross validation score is: 38.377167629708964

# %%
score1=cross_val_score(RFR,df,Y,cv=5,scoring='r2')
print(score1)
print(score1.mean())
print("Difference between R2 score and cross validation score is:",(r2_score(y_test,pred_RFR)-score1.mean())*100)
# Out:
# [ 0.24442549 -4.8122126   0.07685133  0.48012948  0.65742627]
# -0.6706760040007144
# Difference between R2 score and cross validation score is: 97.84036194252346

# %%
score2=cross_val_score(knn,df,Y,cv=5,scoring='r2')
print(score2)
print(score2.mean())
print("Difference between R2 score and cross validation score is:",(r2_score(y_test,pred_knn)-score2.mean())*100)
# Out:
# [-0.39907638 -0.27877863 -0.66117289 -0.32749765 -0.1448284 ]
# -0.3622707873213181
# Difference between R2 score and cross validation score is: -52.801453171724255

# %%
score3=cross_val_score(GBR,df,Y,cv=5,scoring='r2')
print(score3)
print(score3.mean())
print("Difference between R2 score and cross validation score is:",(r2_score(y_test,pred_GBR)-score3.mean())*100)
# Out:
# [ 0.01317995 -7.19719577  0.22313916  0.65335666  0.50910482]
# -1.159683035820119
# Difference between R2 score and cross validation score is: 157.29041034863863

# %%
score4=cross_val_score(lasso,df,Y,cv=5,scoring='r2')
print(score4)
print(score4.mean())
print("Difference between R2 score and cross validation score is:",(r2_score(y_test,pred_lasso)-score4.mean())*100)
# Out:
# [ 0.16629268 -1.39110743  0.28377     0.3475667   0.82220852]
# 0.045746094740445976
# Difference between R2 score and cross validation score is: 33.92896829076849

# %%
score5=cross_val_score(rd,df,Y,cv=5,scoring='r2')
print(score5)
print(score5.mean())
print("Difference between R2 score and cross validation score is:",(r2_score(y_test,pred_rd)-score2.mean())*100)
# Out:
# [ 0.25608437 -1.07327962  0.51489118  0.65241288  0.79373021]
# 0.22876780335370334
# Difference between R2 score and cross validation score is: 95.33980720439462

# %%
score6=cross_val_score(dtr,df,Y,cv=5,scoring='r2')
print(score6)
print(score6.mean())
print("Difference between R2 score and cross validation score is:",(r2_score(y_test,pred_dtr)-score6.mean())*100)
# Out:
# [ -0.169627   -11.54961832  -0.42916984   0.21821036  -0.05798817]
# -2.3976385927016772
# Difference between R2 score and cross validation score is: 200.87400971111532

# %%
score7=cross_val_score(svr,df,Y,cv=5,scoring='r2')
print(score7)
print(score7.mean())
print("Difference between R2 score and cross validation score is:",(r2_score(y_test,pred_svr)-score7.mean())*100)
# Out:
# [-0.16116351 -0.7612858  -0.32021177 -0.75337035 -0.30195118]
# -0.45959652146905833
# Difference between R2 score and cross validation score is: 13.980334270420341

# %%
score8=cross_val_score(etr,df,Y,cv=5,scoring='r2')
print(score8)
print(score8.mean())
print("Difference between R2 score and cross validation score is:",(r2_score(y_test,pred_etr)-score8.mean())*100)
# Out:
# [-0.14222069 -2.54782176  0.33379482  0.38085162  0.76357266]
# -0.24236466954916874
# Difference between R2 score and cross validation score is: 56.54624388730489

# %%
from sklearn.model_selection import GridSearchCV

param = param = {
    'C': [1.0, 0.05, 0.4, 2],
    'kernel': ['linear', 'rbf'],
    'gamma': ['scale', 'auto'],
}

gscv = GridSearchCV(SVR(), param, cv=5)
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVR(),
#              param_grid={'C': [1.0, 0.05, 0.4, 2], 'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'rbf']})

# %%
gscv.best_params_
# Out:
# {'C': 0.4, 'gamma': 'scale', 'kernel': 'linear'}

# %%
Model=SVR(C= 0.4, gamma='scale', kernel='linear')

# %%
Model.fit(x_train,y_train)
pred=Model.predict(x_test)
print('R2_score:',r2_score(y_test,pred))
print('Mean Absolute Error:', mean_absolute_error(y_test,pred))
print('Mean Squared Error:',mean_squared_error(y_test,pred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.30448093089686146
# Mean Absolute Error: 6.758499612059104
# Mean Squared Error: 62.84666838474141
# Root Mean Squared Error: 7.927589065077819

# %%
import joblib

# %%
import pickle
filename="Basketball.pkl"
pickle.dump(Model,open(filename,'wb'))

# %%
import pickle
loaded_model=pickle.load(open('Basketball.pkl',"rb"))
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 30.448093089686147

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],y_test[:]],index=["predicted","Original"])
conclusion
# Out:
#                    0          1          2          3         4         5  \
# predicted  99.234642  85.061396  80.229153  81.336544  92.65552  92.96665
# Original   92.000000  98.000000  87.000000  79.000000  80.00000  95.00000
#
#                    6          7
# predicted  83.182576  74.915912
# Original   81.000000  67.000000
