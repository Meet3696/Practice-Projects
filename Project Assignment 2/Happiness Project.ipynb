# %%
# import necessary Library
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings ('ignore')

# %%
df=pd.read_csv("https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/World%20Happiness/happiness_score_dataset.csv")
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %% [markdown]
# #### Dataset contain total 12 columns
# #### 2 columns are alphabetically and other 10 are numerical columns

# %%
# shape of the dataset
df.shape
# Out:
# (158, 12)

# %% [markdown]
# #### dataset contain 158 rows and 12 columns & out of 12 columns 1 is the target variable column

# %%
# CHecking duplicate data in the dataset
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #####      no duplicates values present in the dataset

# %%
# Checking null values in the dataset
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# ###### Dataset contains all the needed data, there is no Null value present in the dataset

# %%
# Checking information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
# Checking all columns datatypes
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# #####        10 columns have numerical datatypes: 9 column have float data and 1 column have integer datatype
# #####         2 columns have object datatypes

# %%
# Visualizing null values using heatmap

sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
# Checking list of columns
df.columns.tolist()
# Out:
# ['Country',
#  'Region',
#  'Happiness Rank',
#  'Happiness Score',
#  'Standard Error',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Trust (Government Corruption)',
#  'Generosity',
#  'Dystopia Residual']

# %%
# unique values in the dataset
df.nunique().to_frame('No. of unique values')
# Out:
#                                No. of unique values
# Country                                         158
# Region                                           10
# Happiness Rank                                  157
# Happiness Score                                 157
# Standard Error                                  153
# Economy (GDP per Capita)                        158
# Family                                          158
# Health (Life Expectancy)                        157
# Freedom                                         158
# Trust (Government Corruption)                   157
# Generosity                                      158
# Dystopia Residual                               158

# %%
# unique values in each columns
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# Switzerland    1
# Bangladesh     1
# Greece         1
# Lebanon        1
# Hungary        1
#               ..
# Kazakhstan     1
# Slovenia       1
# Lithuania      1
# Nicaragua      1
# Togo           1
# Name: Country, Length: 158, dtype: int64
#
#
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64
#
#
# 82     2
# 1      1
# 110    1
# 103    1
# 104    1
#       ..
# 54     1
# 55     1
# 56     1
# 57     1
# 158    1
# Name: Happiness Rank, Length: 157, dtype: int64
#
#
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# 5.848    1
# 5.833    1
# 5.828    1
# ...

# %% [markdown]
# #### All columns have the most of all unique value except the column" Region" . So based on analysis 'Region'  column have the categorical data and remaining all column have the continuous data

# %%
# Seperating Numerical Columns
num_column=[]
for i in df.dtypes.index:
    if df.dtypes[i]!= "object":
        num_column.append(i)
print(num_column)
# Out:
# ['Happiness Rank', 'Happiness Score', 'Standard Error', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual']

# %%
# Checking no. of numerical column
print(len(num_column))
# Out:
# 10

# %%
# Checking all categorical data in the Region column
v=df['Region'].unique()
v
# Out:
# array(['Western Europe', 'North America', 'Australia and New Zealand',
#        'Middle East and Northern Africa', 'Latin America and Caribbean',
#        'Southeastern Asia', 'Central and Eastern Europe', 'Eastern Asia',
#        'Sub-Saharan Africa', 'Southern Asia'], dtype=object)

# %%
len(v)
# Out:
# 10

# %% [markdown]
# #### There are total 10 categorical data present in the Region column

# %% [markdown]
# # Description of Dataset

# %%
# statistical summary of numerical columns
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# #### Analyze the data and some point to be observed is
# #### 1. all columns have the 158 counts, means no nullls alue present in the dataset
# #### 2. In all columns more or less mean value is similar to median (50%) , that means data is not skewed, but we check skewness later.
# #### 3. There is no major difference between the max value and 25%, 50% , 75% data, it means that there is no major outliers present in the dataset.

# %%
# checking statistical correlation with graphs
plt.figure(figsize=(22,10))
sns.heatmap(df.describe(),annot=True,fmt='.3f',linewidth=0.2,linecolor='black',cmap='Spectral')

plt.xlabel('Figure',fontsize=14)
plt.ylabel('Features_Name',fontsize=14)
plt.title('Descriptive graphs',fontsize=20)
plt.show()

# %% [markdown]
# # Visualizing data

# %%
sns.lmplot(x="Economy (GDP per Capita)", y="Happiness Score",data=df,palette='colorblind')

# %% [markdown]
# ### Economy (GDP per Capita has a positive correlation with Happiness Score

# %%
sns.lmplot(x="Family", y="Happiness Score",data=df,palette='colorblind')

# %% [markdown]
# ### looks family has also positive correlation with the Happiness score

# %%
sns.lmplot(x="Health (Life Expectancy)", y="Happiness Score",data=df,palette='colorblind')

# %% [markdown]
# ### Health (Life Expectancy) has a positive correlation  with th target variable Happiness Score

# %%
sns.lmplot(x="Freedom", y="Happiness Score",data=df,palette='colorblind')

# %% [markdown]
# ### Freedom has  also positive correlation with the Happiness score, but some data points are far from the regline

# %%
sns.lmplot(x="Generosity", y="Happiness Score",data=df,palette='colorblind')

# %% [markdown]
# ### Generosity has a very low positive correlation with the Happiness score

# %%
sns.lmplot(x="Trust (Government Corruption)", y="Happiness Score",data=df,palette='colorblind')

# %% [markdown]
# ### Trust (Government Corruption) has a positive correlation with the Happiness score

# %%
sns.lmplot(x="Dystopia Residual", y="Happiness Score",data=df,palette='colorblind')

# %% [markdown]
# ### Dystopia Residual has a positive correlation with the Happiness score

# %% [markdown]
# #

# %%
sns.pairplot(data=df,palette='DarkZ')

# %% [markdown]
# #### we can visualize that Economy(GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption) have a positive correlation with the Happiness Score

# %%
num_column

zi=num_column
zi
# Out:
# ['Happiness Rank',
#  'Happiness Score',
#  'Standard Error',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Trust (Government Corruption)',
#  'Generosity',
#  'Dystopia Residual']

# %% [markdown]
# ##

# %% [markdown]
# #

# %%
## Let's Check the outliers, if present in the dataset or not
plt.figure(figsize=(20,25))
p=1
for i in vi:
    if p<=10:
        plt.subplot(2,5,p)
        sns.boxplot(df[i],palette="Set2_r")
        plt.xlabel(i)
    p+=1
plt.show()

# %% [markdown]
# #### As per given problem statement 7 columns needed for model building . Out of 7 column Family, Generosity, Trust (Government Corruption) and Dystopia Residual have a outliers data, but hhere we have very less data so we not remove any outliers

# %%
## Data distribution in each column
plt.figure(figsize=(20,25),facecolor='green')
plotnumber=1
for i in vi:
    if plotnumber<=10:
        ax=plt.subplot(3,4,plotnumber)
        sns.distplot(df[i],color='b')
        plt.xlabel(i, fontsize=18)
    plotnumber+=1
plt.show()

# %%
# checking skewness for the data
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
# Separate Target independent varible 
id_var=df[['Economy (GDP per Capita)','Family','Health (Life Expectancy)','Freedom','Generosity','Trust (Government Corruption)','Dystopia Residual']]

# %%
id_var.head()
# Out:
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Generosity  Trust (Government Corruption)  Dystopia Residual
# 0     0.29678                        0.41978            2.51738
# 1     0.43630                        0.14145            2.70201
# 2     0.34139                        0.48357            2.49204
# 3     0.34699                        0.36503            2.46531
# 4     0.45811                        0.32957            2.45176

# %%
# Separete target Variable
dep_var=df['Happiness Score']

# %%
dep_var.tail()
# Out:
# 153    3.465
# 154    3.340
# 155    3.006
# 156    2.905
# 157    2.839
# Name: Happiness Score, dtype: float64

# %%
#Now check skewness for dependent variable
dep_var.skew()
# Out:
# 0.09776909409344678

# %% [markdown]
# #### dependent variable data is normally skewed , so  we need not on perform any operation on it

# %%
# Now check skewness for independent variable
id_var.skew()
# Out:
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Generosity                       1.001961
# Trust (Government Corruption)    1.385463
# Dystopia Residual               -0.238911
# dtype: float64

# %%
# removing skewness of Trust column using cuberoot method
try1=np.cbrt(id_var['Trust (Government Corruption)'])
try1.skew()
# Out:
# 0.011931998380344316

# %%
try2=np.log(id_var['Trust (Government Corruption)'])
try2.skew()
# Out:
# nan

# %%
id_var['Trust (Government Corruption)']=np.cbrt(id_var['Trust (Government Corruption)'])

# %% [markdown]
# ##### using cuberoot method we removing skewness from the TRUST column

# %%
# let's recheck the skewness
id_var.skew()
# Out:
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Generosity                       1.001961
# Trust (Government Corruption)    0.011932
# Dystopia Residual               -0.238911
# dtype: float64

# %%
# apply cuberoot method to Generosity column
id_var['Generosity']=np.cbrt(id_var['Generosity'])

# %%
id_var.skew()
# Out:
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Generosity                      -0.961079
# Trust (Government Corruption)    0.011932
# Dystopia Residual               -0.238911
# dtype: float64

# %%
## checking Correlation target variable and independent variable
need_column=df[['Economy (GDP per Capita)','Family','Health (Life Expectancy)','Freedom','Generosity','Trust (Government Corruption)','Dystopia Residual','Happiness Score']]

need_column.corr()
# Out:
#                                Economy (GDP per Capita)    Family  \
# Economy (GDP per Capita)                       1.000000  0.645299
# Family                                         0.645299  1.000000
# Health (Life Expectancy)                       0.816478  0.531104
# Freedom                                        0.370300  0.441518
# Generosity                                    -0.010465  0.087513
# Trust (Government Corruption)                  0.128716  0.068453
# Dystopia Residual                              0.040059  0.148117
# Happiness Score                                0.780966  0.740605
#
#                                Health (Life Expectancy)   Freedom  Generosity  \
# Economy (GDP per Capita)                       0.816478  0.370300   -0.010465
# Family                                         0.531104  0.441518    0.087513
# Health (Life Expectancy)                       1.000000  0.360477    0.108335
# ...

# %%
plt.figure(figsize=(26,14))
sns.heatmap(need_column.corr(),annot=True,fmt='0.3f',linewidth=0.3,linecolor='black',cmap='Spectral')
plt.xlabel('Figure',fontsize=14)
plt.ylabel('Features_Name',fontsize=14)
plt.title('Descriptive Graph', fontsize=20)
plt.show()

# %% [markdown]
# #### base on correlation heatmap Economy and Health have a high positive correlation is -0.816
# #### we keep all the columns for model building because of there is no very high correlation obeserved except Economy and Health
# #### Economy, Family and Health have highly correlated with the Dependent variable

# %%
## Apply Standard scaler to features
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(id_var),columns=id_var.columns)
x.head()
# Out:
#    Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                  1.369621  1.320281                  1.263408  1.577438
# 1                  1.135226  1.514458                  1.289434  1.332456
# 2                  1.192861  1.361054                  0.992229  1.469659
# 3                  1.525130  1.251922                  1.035145  1.605131
# 4                  1.194876  1.221204                  1.118054  1.360416
#
#    Generosity  Trust (Government Corruption)  Dystopia Residual
# 0    0.576890                       1.826993           0.758258
# 1    1.325808                       0.260958           1.092857
# 2    0.837993                       2.075620           0.712335
# 3    0.869128                       1.592625           0.663893
# 4    1.427657                       1.428028           0.639337

# %%
## Checking Variance Inflation Factor(VIF)
from statsmodels.stats.outliers_influence import variance_inflation_factor


vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(x.values,i) for i in range (len(x.columns))]
vif
# Out:
#    VIF values
# 0    4.031884
# 1    1.953270
# 2    3.123392
# 3    1.815661
# 4    1.318137
# 5    1.332138
# 6    1.037818

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# ## Model  Building

# %%
# importing Necessary library
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge
from sklearn.svm import SVR
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
# Finding the best Random state
maxAccu=0
maxRS=0

for i in range(1,300):
    x_train,x_test,y_train,y_test=train_test_split(x,dep_var,test_size=0.25,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i

print("maximum r2 score is ",maxAccu,"on Random state",maxRS)
# Out:
# maximum r2 score is  0.9989951839541561 on Random state 257

# %%
x_train,x_test,y_train,y_test=train_test_split(x,dep_var,test_size=0.25,random_state=i)

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
pred_LR=LR.predict(x_test)
pred_train=LR.predict(x_train)

print('R2_score:',r2_score(y_test,pred_LR))
print('R2_score on training Data:', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test,pred_LR))
print('Mean Squared Error:',mean_squared_error(y_test,pred_LR))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2_score: 0.9948614091844954
# R2_score on training Data: 99.71953901917578
# Mean Absolute Error: 0.043128496893066526
# Mean Squared Error: 0.006323077094358443
# Root Mean Squared Error: 0.07951777847977422

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
pred_RFR=RFR.predict(x_test)
pred_train=RFR.predict(x_train)

print('R2_score:',r2_score(y_test,pred_RFR))
print('R2_score on training Data:', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test,pred_RFR))
print('Mean Squared Error:',mean_squared_error(y_test,pred_RFR))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# R2_score: 0.9105074447575868
# R2_score on training Data: 98.74794510181184
# Mean Absolute Error: 0.24532625000000002
# Mean Squared Error: 0.11012130494249991
# Root Mean Squared Error: 0.331845302727792

# %%
knn=KNN()
knn.fit(x_train,y_train)
pred_knn=knn.predict(x_test)
pred_train=knn.predict(x_train)

print('R2_score:',r2_score(y_test,pred_knn))
print('R2_score on training Data:', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test,pred_knn))
print('Mean Squared Error:',mean_squared_error(y_test,pred_knn))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred_knn)))
# Out:
# R2_score: 0.8763568198588648
# R2_score on training Data: 94.40078414532569
# Mean Absolute Error: 0.29890000000000005
# Mean Squared Error: 0.152143922
# Root Mean Squared Error: 0.3900563061918112

# %%
GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_GBR=GBR.predict(x_test)
pred_train=GBR.predict(x_train)

print('R2_score:',r2_score(y_test,pred_GBR))
print('R2_score on training Data:', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test,pred_GBR))
print('Mean Squared Error:',mean_squared_error(y_test,pred_GBR))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred_GBR)))
# Out:
# R2_score: 0.9437396526249865
# R2_score on training Data: 99.92781266449275
# Mean Absolute Error: 0.2030031684583446
# Mean Squared Error: 0.06922880738708229
# Root Mean Squared Error: 0.2631136776890975

# %%
lasso=Lasso()
lasso.fit(x_train,y_train)
pred_lasso=lasso.predict(x_test)
pred_train=lasso.predict(x_train)

print('R2_score:',r2_score(y_test,pred_lasso))
print('R2_score on training Data:', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test,pred_lasso))
print('Mean Squared Error:',mean_squared_error(y_test,pred_lasso))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred_lasso)))
# Out:
# R2_score: -0.007932173337881432
# R2_score on training Data: 0.0
# Mean Absolute Error: 0.9118745762711866
# Mean Squared Error: 1.2402686002298196
# Root Mean Squared Error: 1.113673471099056

# %%
rd=Ridge()
rd.fit(x_train,y_train)
pred_rd=rd.predict(x_test)
pred_train=rd.predict(x_train)

print('R2_score:',r2_score(y_test,pred_rd))
print('R2_score on training Data:', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test,pred_rd))
print('Mean Squared Error:',mean_squared_error(y_test,pred_rd))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# R2_score: 0.9948230806034795
# R2_score on training Data: 99.71676163679287
# Mean Absolute Error: 0.04662449494717054
# Mean Squared Error: 0.006370240719831435
# Root Mean Squared Error: 0.07981378778025408

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred_dtr=dtr.predict(x_test)
pred_train=dtr.predict(x_train)

print('R2_score:',r2_score(y_test,pred_dtr))
print('R2_score on training Data:', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test,pred_dtr))
print('Mean Squared Error:',mean_squared_error(y_test,pred_dtr))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred_dtr)))
# Out:
# R2_score: 0.8181564033272365
# R2_score on training Data: 100.0
# Mean Absolute Error: 0.3555
# Mean Squared Error: 0.22375999999999996
# Root Mean Squared Error: 0.47303276842096253

# %%
svr=SVR()
svr.fit(x_train,y_train)
pred_svr=svr.predict(x_test)
pred_train=svr.predict(x_train)

print('R2_score:',r2_score(y_test,pred_svr))
print('R2_score on training Data:', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test,pred_svr))
print('Mean Squared Error:',mean_squared_error(y_test,pred_svr))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred_svr)))
# Out:
# R2_score: 0.9554261943148423
# R2_score on training Data: 98.84969457749123
# Mean Absolute Error: 0.1767822816272982
# Mean Squared Error: 0.05484842437459754
# Root Mean Squared Error: 0.23419740471362516

# %%
etr=ExtraTreesRegressor()
etr.fit(x_train,y_train)
pred_etr=etr.predict(x_test)
pred_train=etr.predict(x_train)

print('R2_score:',r2_score(y_test,pred_etr))
print('R2_score on training Data:', r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test,pred_etr))
print('Mean Squared Error:',mean_squared_error(y_test,pred_etr))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred_etr)))
# Out:
# R2_score: 0.9359012759098302
# R2_score on training Data: 100.0
# Mean Absolute Error: 0.21469975000000024
# Mean Squared Error: 0.07887399262249982
# Root Mean Squared Error: 0.2808451399303535

# %% [markdown]
# #

# %% [markdown]
# ## Check score

# %%
score=cross_val_score(LR,x,dep_var,cv=5,scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 score and cross validation score is:",(r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [0.90974229 0.89551177 0.87337843 0.71588176 0.97525449]
# 0.8739537465794068
# Difference between R2 score and cross validation score is: 12.090766260508856

# %%
score1=cross_val_score(RFR,x,dep_var,cv=5,scoring='r2')
print(score1)
print(score1.mean())
print("Difference between R2 score and cross validation score is:",(r2_score(y_test,pred_RFR)-score1.mean())*100)
# Out:
# [-6.7657301  -0.97122909 -1.15751866 -1.34144527 -5.60717153]
# -3.168618931514616
# Difference between R2 score and cross validation score is: 407.9126376272203

# %%
score2=cross_val_score(knn,x,dep_var,cv=5,scoring='r2')
print(score2)
print(score2.mean())
print("Difference between R2 score and cross validation score is:",(r2_score(y_test,pred_knn)-score2.mean())*100)
# Out:
# [-9.01989105 -3.52062298 -1.4758421  -5.26240461 -4.63674703]
# -4.783101552244302
# Difference between R2 score and cross validation score is: 565.9458372103167
